# %% [markdown]
# <a href="https://colab.research.google.com/github/YihanMou0511/441B/blob/main/Lecture1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive/',force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
df=pd.read_csv('/content/gdrive/MyDrive/441B/Fatalities.csv')

# %%
plt.figure(figsize=(12,5))
plt.plot(df['drinkage'])
plt.title('Drinkage')
plt.xlabel('index')
plt.ylabel('Drinkage')
plt.show()

# %% [markdown]
# Drinkage varies among different index.
